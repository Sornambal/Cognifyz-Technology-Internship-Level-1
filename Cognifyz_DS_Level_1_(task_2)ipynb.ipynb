# %% [markdown]
# <a href="https://colab.research.google.com/github/Sornambal/Cognifyz-Technology-Internship-Level-1/blob/main/Cognifyz_DS_Level_1_(task_2)ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("/content/Dataset .csv")

# %%
# 1. Basic statistical measures for numerical columns
print("📊 Basic Statistical Summary:\n")
print(df.describe())
# Out:
# 📊 Basic Statistical Summary:
#
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# 2. Median for numerical columns
print("\n📏 Median of Numerical Columns:\n")
print(df.median(numeric_only=True))
# Out:
# 📏 Median of Numerical Columns:
#
# Restaurant ID           6.004089e+06
# Country Code            1.000000e+00
# Longitude               7.719196e+01
# Latitude                2.857047e+01
# Average Cost for two    4.000000e+02
# Price range             2.000000e+00
# Aggregate rating        3.200000e+00
# Votes                   3.100000e+01
# dtype: float64

# %%
# 3. Standard deviation for numerical columns
print("\n📐 Standard Deviation of Numerical Columns:\n")
print(df.std(numeric_only=True))
# Out:
# 📐 Standard Deviation of Numerical Columns:
#
# Restaurant ID           8.791521e+06
# Country Code            5.675055e+01
# Longitude               4.146706e+01
# Latitude                1.100794e+01
# Average Cost for two    1.612118e+04
# Price range             9.056088e-01
# Aggregate rating        1.516378e+00
# Votes                   4.301691e+02
# dtype: float64

# %%
# 4. Distribution of categorical variables
print("\n🌍 Country Code Distribution:\n")
print(df["Country Code"].value_counts().head(10))
print("\n🏙️ Top 10 Cities by Restaurant Count:\n")
print(df["City"].value_counts().head(10))

print("\n🍽️ Top 10 Cuisines by Occurrence:\n")
print(df["Cuisines"].value_counts().head(10))
# Out:
# 🌍 Country Code Distribution:
#
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# Name: count, dtype: int64
#
# 🏙️ Top 10 Cities by Restaurant Count:
#
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Lucknow           21
# Ahmedabad         21
# Amritsar          21
# Guwahati          21
# Name: count, dtype: int64
#
# 🍽️ Top 10 Cuisines by Occurrence:
#
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# ...

# %%
# 5.Visualizations
plt.figure(figsize=(12, 5))
sns.countplot(data=df, x='Price range', palette='pastel')
plt.title("Distribution of Price Ranges")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.show()

plt.figure(figsize=(14, 6))
top_cities = df['City'].value_counts().head(10)
sns.barplot(x=top_cities.index, y=top_cities.values, palette="Set2")
plt.xticks(rotation=45)
plt.title("Top 10 Cities with Most Restaurants")
plt.xlabel("City")
plt.ylabel("Restaurant Count")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-2210210015>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Price range', palette='pastel')
# <ipython-input-7-2210210015>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.index, y=top_cities.values, palette="Set2")
